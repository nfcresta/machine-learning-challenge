# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already satisfied: sklearn in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: scipy>=0.19.1 in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.5.2)
# Requirement already satisfied: joblib>=0.11 in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.19.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from scikit-learn->sklearn) (2.1.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (1.0.1)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df.drop(columns=['koi_disposition'])
y = df['koi_disposition']

selected_features.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(selected_features, y, random_state=1)

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# label encode dataset
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# convert encoded labels to one-hot encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
# create deep learning model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create a Neural Network model here
model2 = Sequential()
model2.add(Dense(units=100, activation='relu', input_dim=40))
model2.add(Dense(units=100, activation='relu'))
model2.add(Dense(units=3, activation='softmax'))

# %%
# Compile and fit the model
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model2.fit(X_train_scaled, y_train_categorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 1s - loss: 0.5673 - accuracy: 0.7219
# Epoch 2/100
# 164/164 - 0s - loss: 0.3789 - accuracy: 0.7980
# Epoch 3/100
# 164/164 - 0s - loss: 0.3568 - accuracy: 0.8190
# Epoch 4/100
# 164/164 - 0s - loss: 0.3555 - accuracy: 0.8249
# Epoch 5/100
# 164/164 - 0s - loss: 0.3531 - accuracy: 0.8215
# Epoch 6/100
# 164/164 - 0s - loss: 0.3420 - accuracy: 0.8358
# Epoch 7/100
# 164/164 - 0s - loss: 0.3358 - accuracy: 0.8383
# Epoch 8/100
# 164/164 - 0s - loss: 0.3309 - accuracy: 0.8463
# Epoch 9/100
# 164/164 - 0s - loss: 0.3252 - accuracy: 0.8426
# Epoch 10/100
# 164/164 - 0s - loss: 0.3228 - accuracy: 0.8467
# Epoch 11/100
# 164/164 - 0s - loss: 0.3168 - accuracy: 0.8549
# Epoch 12/100
# 164/164 - 0s - loss: 0.3127 - accuracy: 0.8592
# Epoch 13/100
# 164/164 - 0s - loss: 0.3129 - accuracy: 0.8602
# Epoch 14/100
# 164/164 - 0s - loss: 0.3124 - accuracy: 0.8596
# Epoch 15/100
# 164/164 - 0s - loss: 0.3019 - accuracy: 0.8646
# Epoch 16/100
# 164/164 - 0s - loss: 0.3041 - accuracy: 0.8617
# Epoch 17/100
# 164/164 - 0s - loss: 0.3029 - accuracy: 0.8611
# Epoch 18/100
# 164/164 - 0s - loss: 0.3017 - accuracy: 0.8646
# Epoch 19/100
# 164/164 - 0s - loss: 0.3010 - accuracy: 0.8636
# Epoch 20/100
# 164/164 - 0s - loss: 0.2918 - accuracy: 0.8741
# Epoch 21/100
# 164/164 - 0s - loss: 0.2929 - accuracy: 0.8718
# Epoch 22/100
# 164/164 - 0s - loss: 0.2891 - accuracy: 0.8753
# Epoch 23/100
# 164/164 - 0s - loss: 0.2890 - accuracy: 0.8739
# Epoch 24/100
# 164/164 - 0s - loss: 0.2892 - accuracy: 0.8755
# Epoch 25/100
# 164/164 - 0s - loss: 0.2879 - accuracy: 0.8772
# Epoch 26/100
# 164/164 - 0s - loss: 0.2873 - accuracy: 0.8737
# Epoch 27/100
# 164/164 - 0s - loss: 0.2816 - accuracy: 0.8779
# Epoch 28/100
# 164/164 - 0s - loss: 0.2842 - accuracy: 0.8768
# Epoch 29/100
# 164/164 - 0s - loss: 0.2788 - accuracy: 0.8768
# Epoch 30/100
# 164/164 - 0s - loss: 0.2757 - accuracy: 0.8852
# Epoch 31/100
# 164/164 - 0s - loss: 0.2792 - accuracy: 0.8747
# Epoch 32/100
# 164/164 - 0s - loss: 0.2776 - accuracy: 0.8781
# Epoch 33/100
# 164/164 - 0s - loss: 0.2761 - accuracy: 0.8819
# Epoch 34/100
# 164/164 - 0s - loss: 0.2769 - accuracy: 0.8789
# Epoch 35/100
# 164/164 - 0s - loss: 0.2766 - accuracy: 0.8787
# Epoch 36/100
# 164/164 - 0s - loss: 0.2728 - accuracy: 0.8821
# Epoch 37/100
# 164/164 - 0s - loss: 0.2813 - accuracy: 0.8728
# Epoch 38/100
# 164/164 - 0s - loss: 0.2636 - accuracy: 0.8837
# Epoch 39/100
# 164/164 - 0s - loss: 0.2663 - accuracy: 0.8850
# Epoch 40/100
# 164/164 - 0s - loss: 0.2728 - accuracy: 0.8840
# Epoch 41/100
# 164/164 - 0s - loss: 0.2670 - accuracy: 0.8835
# Epoch 42/100
# 164/164 - 0s - loss: 0.2646 - accuracy: 0.8867
# Epoch 43/100
# 164/164 - 0s - loss: 0.2616 - accuracy: 0.8865
# Epoch 44/100
# 164/164 - 0s - loss: 0.2618 - accuracy: 0.8875
# Epoch 45/100
# 164/164 - 0s - loss: 0.2599 - accuracy: 0.8869
# Epoch 46/100
# 164/164 - 0s - loss: 0.2620 - accuracy: 0.8871
# Epoch 47/100
# 164/164 - 0s - loss: 0.2607 - accuracy: 0.8852
# Epoch 48/100
# 164/164 - 0s - loss: 0.2607 - accuracy: 0.8856
# Epoch 49/100
# 164/164 - 0s - loss: 0.2581 - accuracy: 0.8882
# Epoch 50/100
# 164/164 - 0s - loss: 0.2528 - accuracy: 0.8894
# Epoch 51/100
# 164/164 - 0s - loss: 0.2576 - accuracy: 0.8819
# Epoch 52/100
# 164/164 - 0s - loss: 0.2554 - accuracy: 0.8888
# Epoch 53/100
# 164/164 - 0s - loss: 0.2549 - accuracy: 0.8888
# Epoch 54/100
# 164/164 - 0s - loss: 0.2558 - accuracy: 0.8886
# Epoch 55/100
# 164/164 - 0s - loss: 0.2486 - accuracy: 0.8941
# Epoch 56/100
# 164/164 - 0s - loss: 0.2532 - accuracy: 0.8877
# Epoch 57/100
# 164/164 - 0s - loss: 0.2546 - accuracy: 0.8880
# Epoch 58/100
# 164/164 - 0s - loss: 0.2484 - accuracy: 0.8926
# Epoch 59/100
# 164/164 - 0s - loss: 0.2460 - accuracy: 0.8962
# Epoch 60/100
# 164/164 - 0s - loss: 0.2464 - accuracy: 0.8907
# Epoch 61/100
# 164/164 - 0s - loss: 0.2445 - accuracy: 0.8938
# Epoch 62/100
# 164/164 - 0s - loss: 0.2472 - accuracy: 0.8959
# Epoch 63/100
# 164/164 - 0s - loss: 0.2430 - accuracy: 0.8938
# Epoch 64/100
# 164/164 - 0s - loss: 0.2424 - accuracy: 0.8957
# Epoch 65/100
# 164/164 - 0s - loss: 0.2491 - accuracy: 0.8896
# Epoch 66/100
# 164/164 - 0s - loss: 0.2508 - accuracy: 0.8899
# Epoch 67/100
# 164/164 - 0s - loss: 0.2401 - accuracy: 0.8949
# Epoch 68/100
# 164/164 - 0s - loss: 0.2401 - accuracy: 0.8972
# Epoch 69/100
# 164/164 - 0s - loss: 0.2404 - accuracy: 0.8928
# Epoch 70/100
# 164/164 - 0s - loss: 0.2351 - accuracy: 0.8953
# Epoch 71/100
# 164/164 - 0s - loss: 0.2512 - accuracy: 0.8867
# Epoch 72/100
# 164/164 - 0s - loss: 0.2390 - accuracy: 0.8961
# Epoch 73/100
# 164/164 - 0s - loss: 0.2387 - accuracy: 0.8962
# Epoch 74/100
# 164/164 - 0s - loss: 0.2351 - accuracy: 0.9014
# Epoch 75/100
# 164/164 - 0s - loss: 0.2377 - accuracy: 0.8964
# Epoch 76/100
# 164/164 - 0s - loss: 0.2374 - accuracy: 0.8947
# Epoch 77/100
# 164/164 - 0s - loss: 0.2354 - accuracy: 0.8972
# Epoch 78/100
# 164/164 - 0s - loss: 0.2374 - accuracy: 0.8930
# Epoch 79/100
# 164/164 - 0s - loss: 0.2485 - accuracy: 0.8869
# Epoch 80/100
# 164/164 - 0s - loss: 0.2372 - accuracy: 0.8951
# Epoch 81/100
# 164/164 - 0s - loss: 0.2355 - accuracy: 0.8980
# Epoch 82/100
# 164/164 - 0s - loss: 0.2310 - accuracy: 0.8980
# Epoch 83/100
# 164/164 - 0s - loss: 0.2400 - accuracy: 0.8934
# Epoch 84/100
# 164/164 - 0s - loss: 0.2367 - accuracy: 0.8962
# Epoch 85/100
# 164/164 - 0s - loss: 0.2303 - accuracy: 0.8968
# Epoch 86/100
# 164/164 - 0s - loss: 0.2286 - accuracy: 0.9002
# Epoch 87/100
# 164/164 - 0s - loss: 0.2399 - accuracy: 0.8919
# Epoch 88/100
# 164/164 - 0s - loss: 0.2267 - accuracy: 0.9001
# Epoch 89/100
# 164/164 - 0s - loss: 0.2341 - accuracy: 0.8959
# Epoch 90/100
# 164/164 - 0s - loss: 0.2305 - accuracy: 0.8964
# Epoch 91/100
# 164/164 - 0s - loss: 0.2317 - accuracy: 0.8980
# Epoch 92/100
# 164/164 - 0s - loss: 0.2335 - accuracy: 0.8964
# Epoch 93/100
# 164/164 - 0s - loss: 0.2322 - accuracy: 0.8989
# Epoch 94/100
# 164/164 - 0s - loss: 0.2296 - accuracy: 0.8989
# Epoch 95/100
# 164/164 - 0s - loss: 0.2245 - accuracy: 0.9001
# Epoch 96/100
# 164/164 - 0s - loss: 0.2305 - accuracy: 0.8999
# Epoch 97/100
# 164/164 - 0s - loss: 0.2316 - accuracy: 0.8972
# Epoch 98/100
# 164/164 - 0s - loss: 0.2281 - accuracy: 0.8997
# Epoch 99/100
# 164/164 - 0s - loss: 0.2240 - accuracy: 0.9031
# Epoch 100/100
# 164/164 - 0s - loss: 0.2225 - accuracy: 0.9001

# %% [markdown]
# # Quantify the Model

# %%
model_loss, model_accuracy = model2.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2379 - accuracy: 0.9045
# Normal Neural Network - Loss: 0.2379235178232193, Accuracy: 0.9044622182846069

# %% [markdown]
# # Predict

# %%
encoded_predictions = model2.predict_classes(X_test_scaled[:10])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:10])}")
# Out:
# Predicted classes: ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'CONFIRMED' 'FALSE POSITIVE']
# Actual Labels: ['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE', 'FALSE POSITIVE']

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'model2.sav'
joblib.dump(model2, filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-f5f149eaf7f6> in <module>
#       5 import joblib
#       6 filename = 'model2.sav'
# ----> 7 joblib.dump(model2, filename)
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
# --> 480             NumpyPickler(f, protocol=protocol).dump(value)
#     481     else:
#     482         NumpyPickler(filename, protocol=protocol).dump(value)
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     844                 write(MARK)
#     845                 for k, v in tmp:
# --> 846                     save(k)
#     847                     save(v)
#     848                 write(SETITEMS)
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     494             reduce = getattr(obj, "__reduce_ex__", None)
#     495             if reduce is not None:
# --> 496                 rv = reduce(self.proto)
#     497             else:
#     498                 reduce = getattr(obj, "__reduce__", None)
#
# TypeError: can't pickle weakref objects
