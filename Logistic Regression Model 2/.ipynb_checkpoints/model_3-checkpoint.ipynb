# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already satisfied: sklearn in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.19.2)
# Requirement already satisfied: scipy>=0.19.1 in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.5.2)
# Requirement already satisfied: joblib>=0.11 in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.0.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /Users/nickcresta/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (1.0.1)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df.drop(columns=['dec', 'koi_kepmag', 'koi_impact_err1', 'koi_impact_err2'])
selected_features.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff  koi_steff_err1  koi_steff_err2  \
# 0          0.003520  ...       5455              81             -81
# 1          0.000581  ...       5853             158            -176
# 2          0.000115  ...       5805             157            -174
# 3          0.001130  ...       6031             169            -211
# 4          0.001900  ...       6046             189            -232
#
#    koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  \
# 0      4.467           0.064          -0.096     0.927          0.105
# 1      4.544           0.044          -0.176     0.868          0.233
# 2      4.564           0.053          -0.168     0.791          0.201
# 3      4.438           0.070          -0.210     1.046          0.334
# 4      4.486           0.054          -0.229     0.972          0.315
#
#    koi_srad_err2         ra
# 0         -0.061  291.93423
# 1         -0.078  297.00482
# 2         -0.067  285.53461
# 3         -0.133  288.75488
# 4         -0.105  296.28613
#
# [5 rows x 37 columns]

# %%
y = df['koi_disposition']
y.head()
# Out:
# 0         CONFIRMED
# 1    FALSE POSITIVE
# 2    FALSE POSITIVE
# 3         CONFIRMED
# 4         CONFIRMED
# Name: koi_disposition, dtype: object

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(selected_features, y, random_state=1)

# %%
X_train.head()
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 3563       CANDIDATE              0              0              0
# 4099       CONFIRMED              0              0              0
# 5460       CANDIDATE              0              0              0
# 1091       CONFIRMED              0              0              0
# 5999       CANDIDATE              0              0              0
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 3563              0   10.548413     5.470000e-05    -5.470000e-05
# 4099              0   24.754385     1.365000e-04    -1.365000e-04
# 5460              0    1.057336     1.230000e-07    -1.230000e-07
# 1091              0  201.118319     1.461000e-03    -1.461000e-03
# 5999              0   91.649983     3.181000e-03    -3.181000e-03
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff  koi_steff_err1  \
# 3563   139.064020          0.004110  ...       6047             120
# 4099   140.207320          0.004460  ...       4852             144
# 5460   131.792007          0.000096  ...       4664             126
# 1091   187.569860          0.005290  ...       5646             101
# 5999   175.715600          0.028600  ...       6705             164
#
#       koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 3563            -133      4.387           0.066          -0.123     1.092
# 4099            -144      4.519           0.078          -0.052     0.804
# 5460            -140      4.594           0.054          -0.027     0.683
# 1091            -112      4.447           0.072          -0.108     0.954
# 5999            -233      4.145           0.164          -0.164     1.608
#
#       koi_srad_err1  koi_srad_err2         ra
# 3563          0.181         -0.097  298.09543
# 4099          0.056         -0.076  295.73535
# 5460          0.054         -0.060  292.18417
# 1091          0.135         -0.083  283.11377
# 5999          0.905         -0.383  294.93198
#
# [5 rows x 37 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# label encode dataset
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# convert encoded labels to one-hot encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-37ca0063e178> in <module>
#       3 from tensorflow.keras.utils import to_categorical
#       4
# ----> 5 X_scaler = MinMaxScaler().fit(X_train)
#       6 X_train_scaled = X_scaler.transform(X_train)
#       7 X_test_scaled = X_scaler.transform(X_test)
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     361         # Reset internal state before fitting
#     362         self._reset()
# --> 363         return self.partial_fit(X, y)
#     364
#     365     def partial_fit(self, X, y=None):
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     396         X = self._validate_data(X, reset=first_pass,
#     397                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 398                                 force_all_finite="allow-nan")
#     399
#     400         data_min = np.nanmin(X, axis=0)
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1779
#    1780     def __array__(self, dtype=None) -> np.ndarray:
# -> 1781         return np.asarray(self._values, dtype=dtype)
#    1782
#    1783     def __array_wrap__(self, result, context=None):
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'CANDIDATE'

# %%
# Create a logistic regression model
from sklearn.linear_model import LogisticRegression
model3 = LogisticRegression(C=10, max_iter=500)
model3.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=10, max_iter=500)

# %% [markdown]
# # Train the Model

# %%
print(f"Training Data Score: {model3.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model3.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8498950982262063
# Testing Data Score: 0.8638443935926774

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
params_grid = {'C': [1, 5, 10],
              'max_iter': [500, 1000, 5000]
              }
grid2 = GridSearchCV(model1, params_grid, verbose=2)

# %%
# Train the model with GridSearch
grid2.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ..................................C=1, max_iter=500; total time=   0.1s
# [CV] END ..................................C=1, max_iter=500; total time=   0.1s
# [CV] END ..................................C=1, max_iter=500; total time=   0.1s
# [CV] END ..................................C=1, max_iter=500; total time=   0.1s
# [CV] END ..................................C=1, max_iter=500; total time=   0.1s
# [CV] END .................................C=1, max_iter=1000; total time=   0.1s
# [CV] END .................................C=1, max_iter=1000; total time=   0.1s
# [CV] END .................................C=1, max_iter=1000; total time=   0.1s
# [CV] END .................................C=1, max_iter=1000; total time=   0.1s
# [CV] END .................................C=1, max_iter=1000; total time=   0.2s
# [CV] END .................................C=1, max_iter=5000; total time=   0.2s
# [CV] END .................................C=1, max_iter=5000; total time=   0.1s
# [CV] END .................................C=1, max_iter=5000; total time=   0.1s
# [CV] END .................................C=1, max_iter=5000; total time=   0.2s
# [CV] END .................................C=1, max_iter=5000; total time=   0.2s
# [CV] END ..................................C=5, max_iter=500; total time=   0.2s
# [CV] END ..................................C=5, max_iter=500; total time=   0.3s
# [CV] END ..................................C=5, max_iter=500; total time=   0.3s
# [CV] END ..................................C=5, max_iter=500; total time=   0.3s
# [CV] END ..................................C=5, max_iter=500; total time=   0.3s
# [CV] END .................................C=5, max_iter=1000; total time=   0.3s
# [CV] END .................................C=5, max_iter=1000; total time=   0.3s
# [CV] END .................................C=5, max_iter=1000; total time=   0.3s
# [CV] END .................................C=5, max_iter=1000; total time=   0.2s
# [CV] END .................................C=5, max_iter=1000; total time=   0.3s
# [CV] END .................................C=5, max_iter=5000; total time=   0.2s
# [CV] END .................................C=5, max_iter=5000; total time=   0.3s
# [CV] END .................................C=5, max_iter=5000; total time=   0.3s
# [CV] END .................................C=5, max_iter=5000; total time=   0.3s
# [CV] END .................................C=5, max_iter=5000; total time=   0.3s
# [CV] END .................................C=10, max_iter=500; total time=   0.4s
# [CV] END .................................C=10, max_iter=500; total time=   0.3s
# [CV] END .................................C=10, max_iter=500; total time=   0.4s
# [CV] END .................................C=10, max_iter=500; total time=   0.4s
# [CV] END .................................C=10, max_iter=500; total time=   0.3s
# [CV] END ................................C=10, max_iter=1000; total time=   0.4s
# [CV] END ................................C=10, max_iter=1000; total time=   0.4s
# [CV] END ................................C=10, max_iter=1000; total time=   0.3s
# [CV] END ................................C=10, max_iter=1000; total time=   0.3s
# [CV] END ................................C=10, max_iter=1000; total time=   0.3s
# [CV] END ................................C=10, max_iter=5000; total time=   0.3s
# [CV] END ................................C=10, max_iter=5000; total time=   0.3s
# [CV] END ................................C=10, max_iter=5000; total time=   0.3s
# [CV] END ................................C=10, max_iter=5000; total time=   0.3s
# [CV] END ................................C=10, max_iter=5000; total time=   0.3s
# GridSearchCV(estimator=LogisticRegression(C=10, max_iter=500),
#              param_grid={'C': [1, 5, 10], 'max_iter': [500, 1000, 5000]},
#              verbose=2)

# %%
print(grid2.best_params_)
print(grid2.best_score_)
# Out:
# {'C': 10, 'max_iter': 500}
# 0.8477937912515738

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
